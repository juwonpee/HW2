# %%
################################################################################
# Copyright (c) 2021 ContinualAI.                                              #
# Copyrights licensed under the MIT License.                                   #
# See the accompanying LICENSE file for terms.                                 #
#                                                                              #
# Date: 01-12-2020                                                             #
# Author(s): Andrea Cossu                                                      #
# E-mail: contact@continualai.org                                              #
# Website: avalanche.continualai.org                                           #
################################################################################

"""
This example trains on Split CIFAR10 with Naive strategy.
In this example each experience has a different task label.
We use a multi-head model with a separate classifier for each task.
"""

import argparse
import torch
from torch.nn import CrossEntropyLoss
from torch.optim import Adam

from avalanche.benchmarks.classic import SplitCIFAR10
from avalanche.models import SimpleMLP, as_multitask
from avalanche.training.supervised import Naive

# %%
# define CNN

import torch.nn as nn
import torch
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=32, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=False),
            nn.Conv2d(in_channels=32, out_channels=32, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=False),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )

        self.fc1 = nn.Linear(32*16*16, 2048)
        self.fc2 = nn.Linear(2048, 512)
        self.fc3 = nn.Linear(512, 128)
        self.fc4 = nn.Linear(128, 32)
        self.fc5 = nn.Linear(32, 10)
            
    def forward(self, x):
        x = self.conv(x)

        x = x.view(-1, 32*16*16)
        x = self.fc1(x)
        x = torch.relu(x)
        x = self.fc2(x)
        x = torch.relu(x)
        x = self.fc3(x)
        x = torch.relu(x)
        x = self.fc4(x)
        x = torch.relu(x)
        x = self.fc5(x)
        x = torch.log_softmax(x, dim=1)
        return x

# %%
################################################################################
# Copyright (c) 2021 ContinualAI.                                              #
# Copyrights licensed under the MIT License.                                   #
# See the accompanying LICENSE file for terms.                                 #
#                                                                              #
# Date: 01-12-2020                                                             #
# Author(s): Andrea Cossu                                                      #
# E-mail: contact@continualai.org                                              #
# Website: avalanche.continualai.org                                           #
################################################################################

"""
This example trains on Split CIFAR10 with Naive strategy.
In this example each experience has a different task label.
We use a multi-head model with a separate classifier for each task.
"""
from avalanche.training.supervised import Naive

# Config
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# Assuming that we are on a CUDA machine, this should print a CUDA device:

print(device)
# model
model = CNN()

# CL Benchmark Creation
benchmark = SplitCIFAR10(n_experiences=5, return_task_id=True)
train_stream = benchmark.train_stream
test_stream = benchmark.test_stream

# Prepare for training & testing
optimizer = Adam(model.parameters(), lr=0.01)
criterion = CrossEntropyLoss()

# Choose a CL strategy
strategy = Naive(
    model=model,
    optimizer=optimizer,
    criterion=criterion,
    train_mb_size=128,
    train_epochs=3,
    eval_mb_size=128,
    device=device,
)

# train and test loop
for train_task in train_stream:
    print(type(train_task))
    strategy.train(train_task, num_workers=0)
    strategy.eval(test_stream)
# Out:
# cpu
# Files already downloaded and verified
# Files already downloaded and verified
# <class 'avalanche.benchmarks.scenarios.new_classes.nc_scenario.NCExperience'>
# -- >> Start of training phase << --
#  66%|██████▌   | 52/79 [01:38<09:45, 21.68s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 51
#      49 for train_task in train_stream:
#      50     print(type(train_task))
# ---> 51     strategy.train(train_task, num_workers=0)
#      52     strategy.eval(test_stream)
#
# File ~/.local/lib/python3.10/site-packages/avalanche/training/templates/base_sgd.py:146, in BaseSGDTemplate.train(self, experiences, eval_streams, **kwargs)
#     139 def train(self,
#     140           experiences: Union[CLExperience,
#     141                              ExpSequence],
#     142           eval_streams: Optional[Sequence[Union[CLExperience,
#     143                                                 ExpSequence]]] = None,
#     144           **kwargs):
# --> 146     super().train(experiences, eval_streams, **kwargs)
#     147     return self.evaluator.get_last_metrics()
#
# File ~/.local/lib/python3.10/site-packages/avalanche/training/templates/base.py:116, in BaseTemplate.train(self, experiences, eval_streams, **kwargs)
#     114 for self.experience in experiences:
#     115     self._before_training_exp(**kwargs)
# --> 116     self._train_exp(self.experience, eval_streams, **kwargs)
#     117     self._after_training_exp(**kwargs)
#     118 self._after_training(**kwargs)
#
# File ~/.local/lib/python3.10/site-packages/avalanche/training/templates/base_sgd.py:264, in BaseSGDTemplate._train_exp(self, experience, eval_streams, **kwargs)
#     261     self._stop_training = False
#     262     break
# --> 264 self.training_epoch(**kwargs)
#     265 self._after_training_epoch(**kwargs)
#
# File ~/.local/lib/python3.10/site-packages/avalanche/training/templates/update_type/sgd_update.py:28, in SGDUpdate.training_epoch(self, **kwargs)
#      25 self.loss += self.criterion()
#      27 self._before_backward(**kwargs)
# ---> 28 self.backward()
#      29 self._after_backward(**kwargs)
#      31 # Optimization step
#
# File ~/.local/lib/python3.10/site-packages/avalanche/training/templates/base_sgd.py:200, in BaseSGDTemplate.backward(self)
#     198 def backward(self):
#     199     """Run the backward pass."""
# --> 200     self.loss.backward()
#
# File ~/.local/lib/python3.10/site-packages/torch/_tensor.py:488, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     478 if has_torch_function_unary(self):
#     479     return handle_torch_function(
#     480         Tensor.backward,
#     481         (self,),
#    (...)
#     486         inputs=inputs,
#     487     )
# --> 488 torch.autograd.backward(
#     489     self, gradient, retain_graph, create_graph, inputs=inputs
#     490 )
#
# File ~/.local/lib/python3.10/site-packages/torch/autograd/__init__.py:197, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     192     retain_graph = create_graph
#     194 # The reason we repeat same the comment below is that
#     195 # some Python versions print out the first line of a multi-line function
#     196 # calls in the traceback and some print out the last line
# --> 197 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     198     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     199     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:
