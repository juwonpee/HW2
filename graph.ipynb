# %%
import matplotlib.pyplot as plt

# %%
plt.suptitle("AGEM")
plt.title("patterns per exp: 256, sample size: 256")
plt.ylabel('Accuracy')
plt.xlabel('task')
plt.plot([1,2,3,4,5], [0.6221, 0.6403, 0.6877, 0.6811, 0.7780], label="Epoch 1")
plt.plot([1,2,3,4,5], [0.5891, 0.6174, 0.5810, 0.6994, 0.6928], label="Epoch 3")
plt.plot([1,2,3,4,5], [0.5660, 0.5440, 0.5681, 0.5635, 0.5989], label="Epoch 3")
plt.legend()
plt.show()

# %%
plt.suptitle("Naive")
plt.title("Replay")
plt.ylabel('Accuracy')
plt.xlabel('task')
plt.xticks([1,2,3,4,5])
plt.plot([1,2,3,4,5], [0.4082, 0.5936, 0.6761, 0.7302, 0.7270], label="Epoch 3")
plt.plot([1,2,3,4,5], [0.5501, 0.6272, 0.7047, 0.7446, 0.7805], label="Epoch 5")
plt.plot([1,2,3,4,5], [0.5411, 0.6764, 0.6957, 0.7392, 0.7253], label="Epoch 10")
plt.plot([1,2,3,4,5], [0.5965, 0.6637, 0.7012, 0.6904, 0.7159], label="Train 5 times with 1 epoch each")
plt.legend()
plt.show()

# %%
plt.suptitle("LwF")
plt.title("alpha:1 temperature:1")
plt.ylabel('Accuracy')
plt.xlabel('task')
plt.xticks([1,2,3,4,5])
plt.plot([1,2,3,4,5], [0.6962, 0.7221, 0.7760, 0.7862, 0.8346], label="Epoch 1")
plt.plot([1,2,3,4,5], [0.5537, 0.6118, 0.6492, 0.6851, 0.7088], label="Epoch 3")
plt.plot([1,2,3,4,5], [0.6042, 0.6761, 0.7330, 0.7504, 0.8002], label="Epoch 5")
plt.legend()
plt.show()

# %%
plt.suptitle("GDumb")
plt.ylabel('Accuracy')
plt.xlabel('task')
plt.xticks([1,2,3,4,5])
plt.plot([1,2,3,4,5], [0.5125, 0.5580, 0.6290, 0.5659, 0.5987], label="Epoch 1")
plt.plot([1,2,3,4,5], [0.5347, 0.6716, 0.7285, 0.6801, 0.7025], label="Epoch 3")
plt.plot([1,2,3,4,5], [0.5394, 0.5536, 0.5787, 0.6287, 0.6667], label="Epoch 5")
plt.legend()
plt.show()

# %%
plt.suptitle("EWC")
plt.title("lambda: 0.4, decay factor: 0.1")
plt.ylabel('Accuracy')
plt.xlabel('task')
plt.xticks([1,2,3,4,5])
plt.plot([1,2,3,4,5], [0.5125, 0.5580, 0.6290, 0.5659, 0.5987], label="Epoch 1")
plt.plot([1,2,3,4,5], [0.5537, 0.6118, 0.6492, 0.6851, 0.7088], label="Epoch 3")
plt.plot([1,2,3,4,5], [0.6042, 0.6761, 0.7330, 0.7504, 0.8002], label="Epoch 5")
plt.legend()
plt.show()

# %%
plt.suptitle("Joint Training")
# plt.title("alpha:1 temperature:1")
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.xticks([1,3,5])
plt.plot([1,3,5], [0.6962, 0.6000, 0.6328], label="Epoch")
plt.legend()
plt.show()

# %%
# Train to test ratios
# 7:3
plt.suptitle("Naive")
plt.title("Train to test ratio: 8:2")
plt.ylabel('Accuracy')
plt.xlabel('task')
plt.xticks([1,2,3,4,5])
plt.plot([1,2,3,4,5], [0.6127, 0.5961, 0.6012, 0.6981, 0.7226], label="Epoch 1")
plt.plot([1,2,3,4,5], [0.4082, 0.5936, 0.6761, 0.7302, 0.7270], label="Epoch 3")
plt.plot([1,2,3,4,5], [0.5501, 0.6272, 0.7047, 0.7446, 0.7805], label="Epoch 5")
plt.plot([1,2,3,4,5], [0.5411, 0.6764, 0.6957, 0.7392, 0.7253], label="Epoch 10")
plt.legend()
plt.show()

# %%
# Train to test ratios
# 7:3
plt.suptitle("Naive")
plt.title("Train to test ratio: 7:3")
plt.ylabel('Accuracy')
plt.xlabel('task')
plt.xticks([1,2,3,4,5])
plt.plot([1,2,3,4,5], [0.4184, 0.5464, 0.6289, 0.6063, 0.6401], label="Epoch 1")
plt.plot([1,2,3,4,5], [0.5499, 0.6767, 0.6993, 0.7473, 0.7181], label="Epoch 3")
plt.plot([1,2,3,4,5], [0.6090, 0.6490, 0.7047, 0.7232, 0.7789], label="Epoch 5")
plt.plot([1,2,3,4,5], [0.5506, 0.6031, 0.6787, 0.6986, 0.7111], label="Epoch 10")
plt.legend()
plt.show()

# %%
# Train to test ratios
# 6:4
plt.suptitle("Naive")
plt.title("Train to test ratio: 6:4")
plt.ylabel('Accuracy')
plt.xlabel('task')
plt.xticks([1,2,3,4,5])
plt.plot([1,2,3,4,5], [0.5856, 0.6373, 0.5613, 0.6666, 0.6704], label="Epoch 1")
plt.plot([1,2,3,4,5], [0.5607, 0.6048, 0.6719, 0.7052, 0.7619], label="Epoch 3")
plt.plot([1,2,3,4,5], [0.6090, 0.6490, 0.7047, 0.7232, 0.7789], label="Epoch 5")
plt.plot([1,2,3,4,5], [0.6203, 0.6139, 0.7172, 0.7202, 0.7702], label="Epoch 10")
plt.legend()
plt.show()

# %%
# Train to test ratios
# 6:4
plt.suptitle("LwF")
plt.title("Train to test ratio: 6:4")
plt.ylabel('Accuracy')
plt.xlabel('task')
plt.xticks([1,2,3,4,5])
plt.plot([1,2,3,4,5], [0.6313, 0.7036, 0.6751, 0.6939, 0.7050], label="Epoch 1")
plt.plot([1,2,3,4,5], [0.5614, 0.6203, 0.6906, 0.7134, 0.7564], label="Epoch 3")
plt.plot([1,2,3,4,5], [0.4226, 0.5308, 0.6336, 0.7134, 0.7831], label="Epoch 5")
plt.plot([1,2,3,4,5], [0.6079, 0.6103, 0.6916, 0.7428, 0.7741], label="Epoch 10")
plt.legend()
plt.show()

# %%
# Train to test ratios
# 7:3
plt.suptitle("LwF")
plt.title("Train to test ratio: 7:3")
plt.ylabel('Accuracy')
plt.xlabel('task')
plt.xticks([1,2,3,4,5])
plt.plot([1,2,3,4,5], [0.4739, 0.4910, 0.5927, 0.6093, 0.6681], label="Epoch 1")
plt.plot([1,2,3,4,5], [0.4853, 0.5167, 0.5620, 0.6145, 0.6851], label="Epoch 3")
plt.plot([1,2,3,4,5], [0.5369, 0.5717, 0.5755, 0.6945, 0.7821], label="Epoch 5")
plt.plot([1,2,3,4,5], [0.5293, 0.5562, 0.5892, 0.6331, 0.6749], label="Epoch 10")
plt.legend()
plt.show()

# %%
# Train to test ratios
# 7:3
plt.suptitle("LwF")
plt.title("Train to test ratio: 8:2")
plt.ylabel('Accuracy')
plt.xlabel('task')
plt.xticks([1,2,3,4,5])
plt.plot([1,2,3,4,5], [0.6962, 0.7221, 0.7760, 0.7862, 0.8346], label="Epoch 1")
plt.plot([1,2,3,4,5], [0.5537, 0.6118, 0.6492, 0.6851, 0.7088], label="Epoch 3")
plt.plot([1,2,3,4,5], [0.6042, 0.6761, 0.7330, 0.7504, 0.8002], label="Epoch 5")
plt.plot([1,2,3,4,5], [0.5327, 0.5001, 0.5001, 0.5001, 0.5001], label="Epoch 10")
plt.legend()
plt.show()
